# %% [markdown]
# # 실습 1: 데이터 탐색 (Explore Your Data)
#
# > 튜토리얼: [02_basic_data_exploration.md](../tutorials/02_basic_data_exploration.md)
# > 원본: [Kaggle Exercise](https://www.kaggle.com/code/dansbecker/basic-data-exploration)
#
# ---
#
# ## 📝 실습 안내
#
# 이 실습에서는 **Iowa 주택 가격 데이터**를 탐색합니다.
# 튜토리얼에서 Melbourne 데이터로 배운 것을 Iowa 데이터에 직접 적용해봅니다.
#
# **데이터 경로**: `../input/home-data-for-ml-course/train.csv`
#
# ---
# ## 📦 데이터 로드

# %%
import pandas as pd

# Iowa 주택 데이터 로드
iowa_file_path = '../data/home-data-for-ml-course/train.csv'

# 🔧 실습: pd.read_csv()로 데이터를 불러와 home_data 변수에 저장하세요
home_data = ____

# 데이터 타입 확인
print(type(home_data))

# %% [markdown]
# ## 📊 문제 1: 기본 통계 확인
#
# `describe()` 함수로 데이터의 기본 통계를 출력하세요.

# %%
# 🔧 실습: describe()를 사용하여 기본 통계를 출력하세요
home_data.____

# %% [markdown]
# ## 📊 문제 2: SalePrice 평균 구하기
#
# Iowa 데이터에서 **집 판매 가격(`SalePrice`)의 평균값**을 구하세요.

# %%
# 🔧 실습: SalePrice 열의 평균을 구하세요
avg_lot_size = home_data['SalePrice'].____

print(f'평균 판매 가격: ${avg_lot_size:,.0f}')

# %% [markdown]
# ## 📊 문제 3: 가장 오래된 집 찾기
#
# `YearBuilt` 열에서 **가장 오래된 집이 지어진 연도**를 찾으세요.

# %%
# 🔧 실습: YearBuilt 열의 최솟값을 구하세요
oldest_home_age = home_data['YearBuilt'].____

print(f'가장 오래된 집이 지어진 연도: {oldest_home_age}')

# %% [markdown]
# ## 📊 문제 4: 열 목록 확인
#
# 데이터에 어떤 열들이 있는지 확인하세요.

# %%
# 🔧 실습: .columns 속성으로 모든 열 이름을 출력하세요
print(home_data.____)

# %% [markdown]
# ---
#
# ## ✅ 정답 확인

# %%
# 정답 코드 (모두 채운 후 실행해 확인하세요)
import pandas as pd

home_data = pd.read_csv('../data/home-data-for-ml-course/train.csv')

print('=== 기본 통계 ===')
print(home_data.describe())

print(f'\n평균 판매 가격: ${home_data.SalePrice.mean():,.0f}')
print(f'가장 오래된 집: {home_data.YearBuilt.min()}년')
print(f'\n열 목록:')
print(home_data.columns.tolist())

# %% [markdown]
# ---
# ➡️ **다음**: [실습 2: 첫 번째 ML 모델](ex2_first_ml_model.ipynb)
