# %% [markdown]
# # 실습 3: 모델 검증 (Model Validation)
#
# > 튜토리얼: [04_model_validation.md](../tutorials/04_model_validation.md)
#
# ---
#
# ## 📝 실습 안내
#
# Iowa 데이터를 훈련/검증 세트로 나누고, MAE로 모델 성능을 평가합니다.
#
# ---
# ## 📦 데이터 준비 (실행만 하세요)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

iowa_file_path = '../data/home-data-for-ml-course/train.csv'
home_data = pd.read_csv(iowa_file_path)

# 특성과 타겟
y = home_data.SalePrice
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF',
            'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = home_data[features]

print('데이터 준비 완료!')

# %% [markdown]
# ## 📊 문제 1: 훈련/검증 데이터 분리
#
# `train_test_split`으로 데이터를 분리하세요. `random_state=1`을 사용하세요.

# %%
from sklearn.model_selection import train_test_split

# 🔧 실습: train_X, val_X, train_y, val_y 로 분리하세요
train_X, val_X, train_y, val_y = train_test_split(____, ____, random_state=1)

print(f'훈련 데이터: {len(train_X)}개')
print(f'검증 데이터: {len(val_X)}개')

# %% [markdown]
# ## 📊 문제 2: 모델 학습
#
# **훈련 데이터**만 사용하여 결정 트리 모델을 학습시키세요.

# %%
# 🔧 실습: 결정 트리 모델을 만들고 훈련 데이터로 학습시키세요
iowa_model = DecisionTreeRegressor(random_state=1)
iowa_model.fit(____, ____)

print('모델 학습 완료!')

# %% [markdown]
# ## 📊 문제 3: 검증 데이터로 예측
#
# **검증 데이터**에 대해 예측하세요.

# %%
# 🔧 실습: 검증 데이터(val_X)로 예측하세요
val_predictions = iowa_model.predict(____)

print('처음 5개 예측:', val_predictions[:5])
print('처음 5개 실제:', val_y.values[:5])

# %% [markdown]
# ## 📊 문제 4: MAE 계산
#
# 검증 데이터에서의 MAE를 계산하세요.

# %%
from sklearn.metrics import mean_absolute_error

# 🔧 실습: MAE를 계산하세요
val_mae = mean_absolute_error(____, ____)

print(f'검증 MAE: ${val_mae:,.0f}')
print(f'\n→ 평균적으로 예측이 ${val_mae:,.0f} 만큼 빗나갑니다')

# %% [markdown]
# ---
#
# ## 💡 해석
#
# 이 MAE 값이 좋은지 나쁜지 어떻게 판단할까요?

# %%
# MAE와 평균 가격 비교
avg_price = home_data.SalePrice.mean()
print(f'평균 집값: ${avg_price:,.0f}')
print(f'MAE: ${val_mae:,.0f}')
print(f'MAE는 평균 집값의 {val_mae/avg_price*100:.1f}% 입니다')

# %% [markdown]
# ---
#
# ## ✅ 정답 확인

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error

home_data = pd.read_csv('../data/home-data-for-ml-course/train.csv')
y = home_data.SalePrice
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF',
            'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = home_data[features]

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

iowa_model = DecisionTreeRegressor(random_state=1)
iowa_model.fit(train_X, train_y)

val_predictions = iowa_model.predict(val_X)
val_mae = mean_absolute_error(val_y, val_predictions)
print(f'검증 MAE: ${val_mae:,.0f}')

# %% [markdown]
# ---
# ➡️ **다음**: [실습 4: 과소/과대적합](ex4_underfitting_overfitting.ipynb)
